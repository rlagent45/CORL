# %%
# This ensures that a gpu is being used by the current google colab session.

gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Sun Sep 20 10:46:36 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.66       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    24W / 300W |      0MiB / 16130MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# This code block is used to access your google drive

from google.colab import drive
ROOT = "/content/drive"
drive.mount(ROOT)
# Out:
# Mounted at /content/drive

# %%
# Make sure this points to the project folder

# %cd drive/'My Drive'/CORL
# Out:
# /content/drive/My Drive/Colab_Workspace/project_folder/new_mlopt

# %%
# %cd l2i

# %%
# This line will run the l2i code with the below settings using initial solutions
# from a 21 hr attention model

# !python3 run.py --name att_start --problem_seed 1 --num_episode 500 --save_hrs 9 --max_rollout_steps 20000 --initial_solutions ../init_sol/att_21_init_sol.pickle
# Out:
# Sample #0 avg min dist: 14.276492642497495 time for samp: 235.01386976242065
# Sample #1 avg min dist: 14.904340328612744 time for samp: 241.40107131004333
# Sample #2 avg min dist: 14.464606985944906 time for samp: 235.71639680862427
# Sample #3 avg min dist: 14.738782237248362 time for samp: 238.07548260688782
# Sample #4 avg min dist: 15.119898939999052 time for samp: 217.20231366157532
# Sample #5 avg min dist: 15.324522633031785 time for samp: 249.79270315170288
# Sample #6 avg min dist: 15.588629440479659 time for samp: 241.92011666297913
# Sample #7 avg min dist: 16.018964383763617 time for samp: 230.2082986831665
# Sample #8 avg min dist: 16.190057195129576 time for samp: 227.77020978927612
# Sample #9 avg min dist: 16.28131720995916 time for samp: 237.03717947006226
# Sample #10 avg min dist: 16.472979602544687 time for samp: 215.3608899116516
# Sample #11 avg min dist: 16.27228630334975 time for samp: 239.33951997756958
# ...
